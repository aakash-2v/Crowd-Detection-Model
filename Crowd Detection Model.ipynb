# %%
#Importing the packages needed
import cv2
import numpy as np
from ultralytics import YOLO
import datetime
import logging
import csv
import os
from collections import defaultdict
from sklearn.cluster import DBSCAN

# %%
class CrowdDetector:
    def __init__(self, proximity_threshold=100, min_crowd_size=3, 
                 consecutive_frames=10, confidence_threshold=0.5):
        print("Initializing Crowd Detector...")
        
        # Initialize YOLO model
        try:
            self.model = YOLO('yolov8n.pt')
        except Exception as e:
            print(f"Error loading YOLO model: {e}")
            raise
        
        self.proximity_threshold = proximity_threshold
        self.min_crowd_size = min_crowd_size
        self.consecutive_frames = consecutive_frames
        self.confidence_threshold = confidence_threshold
        
        # Initialize tracking variables
        self.crowd_history = []
        self.persistent_crowds = defaultdict(int)
        
        # Setup output directory
        self.output_dir = 'crowd_detection_results'
        os.makedirs(self.output_dir, exist_ok=True)
        
        # Setup CSV logging with timestamp in filename
        timestamp = datetime.datetime.now().strftime("%Y%m%d_%H%M%S")
        self.csv_file = os.path.join(self.output_dir, f'crowd_detection_{timestamp}.csv')
        
        # Initialize CSV file with headers
        with open(self.csv_file, 'w', newline='') as f:
            writer = csv.writer(f)
            writer.writerow(['Frame_Number', 'Person_Count_in_Crowd', 'Timestamp'])
        print(f"CSV file initialized at: {self.csv_file}")
        
        # Setup logging
        log_file = os.path.join(self.output_dir, f'detection_log_{timestamp}.txt')
        logging.basicConfig(
            filename=log_file,
            level=logging.INFO,
            format='%(asctime)s - %(message)s'
        )
        print(f"Log file initialized at: {log_file}")
    
    def log_crowd_detection(self, frame_number, crowd_size, crowd_center):
        timestamp = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        try:
            with open(self.csv_file, 'a', newline='') as f:
                writer = csv.writer(f)
                writer.writerow([
                    frame_number,
                    crowd_size,
                    timestamp
                ])
            logging.info(f"Frame {frame_number}: Detected crowd of {crowd_size} people at location {crowd_center}")
            return True
        except Exception as e:
            print(f"Error logging crowd detection: {e}")
            return False
    
    def analyze_frame(self, frame, frame_number):
        # Run detection
        try:
            results = self.model(frame)[0]
            boxes = []
            
            # Filter for person detections
            for detection in results.boxes.data.tolist():
                x1, y1, x2, y2, conf, class_id = detection
                if int(class_id) == 0 and conf > self.confidence_threshold:
                    boxes.append([x1, y1, x2, y2])
            
            if boxes:
                print(f"Frame {frame_number}: Detected {len(boxes)} people")
            
            # Get person centers
            centers = np.array([[
                (box[0] + box[2]) / 2,
                (box[1] + box[3]) / 2
            ] for box in boxes])
            
            #using DBSCAN for identifying the crowds
            if len(centers) >= self.min_crowd_size:
                clustering = DBSCAN(
                    eps=self.proximity_threshold,
                    min_samples=self.min_crowd_size,
                    metric='euclidean'
                ).fit(centers)
                
                # Group points by cluster
                crowds = defaultdict(list)
                for idx, label in enumerate(clustering.labels_):
                    if label >= 0:
                        crowds[label].append(idx)
                
                # Update crowd history and check persistence
                current_crowds = [group for group in crowds.values() 
                                if len(group) >= self.min_crowd_size]
                
                # Store current frame's crowds
                self.crowd_history.append((frame_number, current_crowds))
                
                # Remove old frames from history
                while len(self.crowd_history) > self.consecutive_frames:
                    self.crowd_history.pop(0)
                
                # Check for persistent crowds
                if len(self.crowd_history) == self.consecutive_frames:
                    for crowd_indices in current_crowds:
                        crowd_centers = centers[crowd_indices]
                        crowd_center = np.mean(crowd_centers, axis=0)
                        
                        # Log the crowd detection
                        self.log_crowd_detection(
                            frame_number,
                            len(crowd_indices),
                            crowd_center
                        )
                        
                        # Visualize the crowd
                        crowd_color = (255, 0, 0)  # Red for crowd
                        
                        # Draw connections between crowd members
                        for i in range(len(crowd_centers)):
                            for j in range(i + 1, len(crowd_centers)):
                                pt1 = tuple(map(int, crowd_centers[i]))
                                pt2 = tuple(map(int, crowd_centers[j]))
                                cv2.line(frame, pt1, pt2, crowd_color, 2)
                        
                        # Draw crowd label
                        label_pos = tuple(map(int, crowd_center))
                        cv2.putText(
                            frame,
                            f"Crowd: {len(crowd_indices)} people",
                            label_pos,
                            cv2.FONT_HERSHEY_SIMPLEX,
                            1,
                            crowd_color,
                            2
                        )
            
            # Draw individual detections
            for box in boxes:
                x1, y1, x2, y2 = map(int, box)
                cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
            
            # Add frame info
            cv2.putText(
                frame,
                f"Frame: {frame_number} | People: {len(boxes)}", 
                (10, 30),
                cv2.FONT_HERSHEY_SIMPLEX,
                1,
                (255, 255, 255),
                2
            )
            
            return frame
            
        except Exception as e:
            print(f"Error analyzing frame {frame_number}: {e}")
            return frame
    
    def process_video(self, video_path, output_path=None):
        print(f"\nProcessing video: {video_path}")
        
        try:
            cap = cv2.VideoCapture(video_path)
            if not cap.isOpened():
                raise ValueError("Error opening video file")
            
            # Get properties of the video
            frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
            frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
            fps = int(cap.get(cv2.CAP_PROP_FPS))
            total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
            
            print(f"Video properties:")
            print(f"- Resolution: {frame_width}x{frame_height}")
            print(f"- FPS: {fps}")
            print(f"- Total frames: {total_frames}")
            
            # Initialize video writer if output path is provided
            if output_path:
                fourcc = cv2.VideoWriter_fourcc(*'mp4v')
                out = cv2.VideoWriter(
                    output_path,
                    fourcc,
                    fps,
                    (frame_width, frame_height)
                )
                print(f"Output video will be saved to: {output_path}")
            
            frame_number = 0
            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    break
                
                frame_number += 1
                if frame_number % 30 == 0:  # Progress update every 30 frames
                    progress = (frame_number / total_frames) * 100
                    print(f"Processing progress: {progress:.1f}%")
                
                # Process frame
                processed_frame = self.analyze_frame(frame, frame_number)
                
                # Save output frame
                if output_path:
                    out.write(processed_frame)
                
                # Display frame
                cv2.imshow('Crowd Detection', processed_frame)
                
                # Break loop on 'q' press
                if cv2.waitKey(1) & 0xFF == ord('q'):
                    print("\nProcessing interrupted by user")
                    break
            
            # Cleanup
            cap.release()
            if output_path:
                out.release()
            cv2.destroyAllWindows()
            
            print("\nProcessing completed!")
            print(f"Results saved to: {self.csv_file}")
            
        except Exception as e:
            print(f"Error processing video: {e}")
            raise

# %%
if __name__ == "__main__":
    try:
        # Create detector
        detector = CrowdDetector(
            proximity_threshold=100,
            min_crowd_size=3,
            consecutive_frames=10,
            confidence_threshold=0.5
        )
        
        # Process video
        input_video = 'dataset_video (1).mp4'  # Replace with your video path
        output_video = 'output_video.mp4'  # Replace with desired output path
        
        if not os.path.exists(input_video):
            raise FileNotFoundError(f"Input video not found: {input_video}")
        
        detector.process_video(input_video, output_video)
        
    except Exception as e:
        print(f"Error running crowd detection: {e}")
# Out:
# Initializing Crowd Detector...
# CSV file initialized at: crowd_detection_results\crowd_detection_20241117_121324.csv
# Log file initialized at: crowd_detection_results\detection_log_20241117_121324.txt
#
# Processing video: dataset_video (1).mp4
# Video properties:
# - Resolution: 1920x1080
# - FPS: 25
# - Total frames: 341
# Output video will be saved to: output_video.mp4
#
# 0: 384x640 37 persons, 2 birds, 75.0ms
# Speed: 4.0ms preprocess, 75.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 1: Detected 22 people
#
# 0: 384x640 38 persons, 3 birds, 101.7ms
# Speed: 4.5ms preprocess, 101.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 2: Detected 21 people
#
# 0: 384x640 35 persons, 3 birds, 83.5ms
# Speed: 3.0ms preprocess, 83.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 3: Detected 20 people
#
# 0: 384x640 37 persons, 3 birds, 79.5ms
# Speed: 8.0ms preprocess, 79.5ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
# Frame 4: Detected 21 people
#
# 0: 384x640 37 persons, 2 birds, 73.6ms
# Speed: 3.0ms preprocess, 73.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 5: Detected 22 people
#
# 0: 384x640 38 persons, 2 birds, 115.6ms
# Speed: 6.0ms preprocess, 115.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 6: Detected 15 people
#
# 0: 384x640 36 persons, 2 birds, 125.6ms
# Speed: 7.0ms preprocess, 125.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 7: Detected 21 people
#
# 0: 384x640 36 persons, 2 birds, 88.5ms
# Speed: 4.0ms preprocess, 88.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 8: Detected 21 people
#
# 0: 384x640 35 persons, 2 birds, 99.5ms
# Speed: 6.0ms preprocess, 99.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 9: Detected 19 people
#
# 0: 384x640 36 persons, 2 birds, 92.6ms
# Speed: 3.0ms preprocess, 92.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 10: Detected 19 people
#
# 0: 384x640 36 persons, 1 bird, 87.5ms
# Speed: 3.0ms preprocess, 87.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 11: Detected 17 people
#
# 0: 384x640 37 persons, 2 birds, 118.5ms
# Speed: 5.0ms preprocess, 118.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 12: Detected 19 people
#
# 0: 384x640 34 persons, 2 birds, 137.4ms
# Speed: 4.0ms preprocess, 137.4ms inference, 6.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 13: Detected 19 people
#
# 0: 384x640 37 persons, 2 birds, 126.5ms
# Speed: 7.0ms preprocess, 126.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 14: Detected 18 people
#
# 0: 384x640 34 persons, 2 birds, 117.5ms
# Speed: 6.0ms preprocess, 117.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 15: Detected 21 people
#
# 0: 384x640 33 persons, 2 birds, 108.3ms
# Speed: 3.0ms preprocess, 108.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 16: Detected 20 people
#
# 0: 384x640 33 persons, 2 birds, 127.5ms
# Speed: 6.0ms preprocess, 127.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 17: Detected 20 people
#
# 0: 384x640 36 persons, 2 birds, 119.5ms
# Speed: 5.0ms preprocess, 119.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 18: Detected 22 people
#
# 0: 384x640 34 persons, 1 bird, 113.5ms
# Speed: 5.0ms preprocess, 113.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 19: Detected 23 people
#
# 0: 384x640 34 persons, 1 traffic light, 1 bird, 1 dog, 106.6ms
# Speed: 4.0ms preprocess, 106.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 20: Detected 26 people
#
# 0: 384x640 33 persons, 1 dog, 107.6ms
# Speed: 4.1ms preprocess, 107.6ms inference, 4.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 21: Detected 21 people
#
# 0: 384x640 33 persons, 1 dog, 97.6ms
# Speed: 4.0ms preprocess, 97.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 22: Detected 22 people
#
# 0: 384x640 33 persons, 1 dog, 108.6ms
# Speed: 4.0ms preprocess, 108.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 23: Detected 20 people
#
# 0: 384x640 33 persons, 1 dog, 111.1ms
# Speed: 8.0ms preprocess, 111.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 24: Detected 20 people
#
# 0: 384x640 34 persons, 1 dog, 96.6ms
# Speed: 5.0ms preprocess, 96.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 25: Detected 19 people
#
# 0: 384x640 35 persons, 1 bird, 1 dog, 118.5ms
# Speed: 5.0ms preprocess, 118.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 26: Detected 19 people
#
# 0: 384x640 36 persons, 98.6ms
# Speed: 4.0ms preprocess, 98.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 27: Detected 22 people
#
# 0: 384x640 35 persons, 101.6ms
# Speed: 9.0ms preprocess, 101.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 28: Detected 22 people
#
# 0: 384x640 35 persons, 119.7ms
# Speed: 3.0ms preprocess, 119.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 29: Detected 21 people
# Processing progress: 8.8%
#
# 0: 384x640 35 persons, 84.6ms
# Speed: 7.0ms preprocess, 84.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 30: Detected 23 people
#
# 0: 384x640 34 persons, 1 bird, 85.6ms
# Speed: 4.0ms preprocess, 85.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 31: Detected 23 people
#
# 0: 384x640 31 persons, 1 bird, 86.3ms
# Speed: 5.9ms preprocess, 86.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 32: Detected 19 people
#
# 0: 384x640 31 persons, 1 bird, 90.5ms
# Speed: 5.0ms preprocess, 90.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 33: Detected 19 people
#
# 0: 384x640 32 persons, 1 bird, 83.5ms
# Speed: 2.0ms preprocess, 83.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 34: Detected 20 people
#
# 0: 384x640 30 persons, 1 bird, 93.6ms
# Speed: 4.0ms preprocess, 93.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 35: Detected 20 people
#
# 0: 384x640 32 persons, 1 bird, 82.5ms
# Speed: 7.0ms preprocess, 82.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 36: Detected 20 people
#
# 0: 384x640 34 persons, 1 bird, 91.6ms
# Speed: 4.0ms preprocess, 91.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 37: Detected 19 people
#
# 0: 384x640 33 persons, 84.6ms
# Speed: 3.0ms preprocess, 84.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 38: Detected 20 people
#
# 0: 384x640 36 persons, 1 bird, 93.5ms
# Speed: 4.0ms preprocess, 93.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 39: Detected 20 people
#
# 0: 384x640 38 persons, 1 bird, 81.5ms
# Speed: 3.0ms preprocess, 81.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 40: Detected 20 people
#
# 0: 384x640 35 persons, 1 bird, 71.5ms
# Speed: 3.0ms preprocess, 71.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 41: Detected 20 people
#
# 0: 384x640 33 persons, 3 birds, 74.6ms
# Speed: 5.0ms preprocess, 74.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 42: Detected 20 people
#
# 0: 384x640 35 persons, 2 birds, 89.5ms
# Speed: 4.0ms preprocess, 89.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 43: Detected 18 people
#
# 0: 384x640 33 persons, 1 bird, 85.5ms
# Speed: 5.0ms preprocess, 85.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 44: Detected 18 people
#
# 0: 384x640 34 persons, 73.0ms
# Speed: 4.0ms preprocess, 73.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 45: Detected 16 people
#
# 0: 384x640 35 persons, 75.5ms
# Speed: 3.0ms preprocess, 75.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 46: Detected 18 people
#
# 0: 384x640 37 persons, 76.2ms
# Speed: 3.0ms preprocess, 76.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 47: Detected 15 people
#
# 0: 384x640 36 persons, 1 bird, 82.5ms
# Speed: 3.0ms preprocess, 82.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 48: Detected 17 people
#
# 0: 384x640 36 persons, 1 bird, 1 dog, 69.0ms
# Speed: 4.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 49: Detected 20 people
#
# 0: 384x640 36 persons, 1 bird, 1 dog, 81.5ms
# Speed: 3.0ms preprocess, 81.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 50: Detected 20 people
#
# 0: 384x640 40 persons, 1 bird, 1 dog, 80.5ms
# Speed: 3.0ms preprocess, 80.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 51: Detected 20 people
#
# 0: 384x640 41 persons, 1 bird, 1 dog, 75.5ms
# Speed: 3.0ms preprocess, 75.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 52: Detected 19 people
#
# 0: 384x640 37 persons, 1 bird, 2 dogs, 84.5ms
# Speed: 3.0ms preprocess, 84.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 53: Detected 21 people
#
# 0: 384x640 38 persons, 1 bird, 1 dog, 77.5ms
# Speed: 3.0ms preprocess, 77.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 54: Detected 22 people
#
# 0: 384x640 40 persons, 1 dog, 70.5ms
# Speed: 4.0ms preprocess, 70.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 55: Detected 23 people
#
# 0: 384x640 37 persons, 66.5ms
# Speed: 4.0ms preprocess, 66.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 56: Detected 22 people
#
# 0: 384x640 39 persons, 1 bird, 67.0ms
# Speed: 3.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 57: Detected 22 people
#
# 0: 384x640 37 persons, 1 bird, 77.0ms
# Speed: 5.0ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 58: Detected 20 people
#
# 0: 384x640 38 persons, 1 bird, 81.5ms
# Speed: 3.0ms preprocess, 81.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 59: Detected 22 people
# Processing progress: 17.6%
#
# 0: 384x640 38 persons, 101.6ms
# Speed: 5.0ms preprocess, 101.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 60: Detected 24 people
#
# 0: 384x640 36 persons, 1 dog, 127.4ms
# Speed: 12.0ms preprocess, 127.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 61: Detected 23 people
#
# 0: 384x640 39 persons, 1 dog, 73.2ms
# Speed: 4.0ms preprocess, 73.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 62: Detected 21 people
#
# 0: 384x640 36 persons, 76.6ms
# Speed: 5.0ms preprocess, 76.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 63: Detected 22 people
#
# 0: 384x640 37 persons, 1 dog, 70.5ms
# Speed: 3.0ms preprocess, 70.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 64: Detected 23 people
#
# 0: 384x640 36 persons, 1 dog, 73.0ms
# Speed: 2.0ms preprocess, 73.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 65: Detected 24 people
#
# 0: 384x640 36 persons, 93.5ms
# Speed: 4.0ms preprocess, 93.5ms inference, 10.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 66: Detected 24 people
#
# 0: 384x640 39 persons, 1 bird, 80.0ms
# Speed: 5.0ms preprocess, 80.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 67: Detected 25 people
#
# 0: 384x640 37 persons, 1 bird, 1 dog, 71.6ms
# Speed: 5.0ms preprocess, 71.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 68: Detected 22 people
#
# 0: 384x640 35 persons, 1 bird, 1 dog, 69.6ms
# Speed: 3.0ms preprocess, 69.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 69: Detected 22 people
#
# 0: 384x640 36 persons, 1 bird, 3 dogs, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 70: Detected 25 people
#
# 0: 384x640 39 persons, 1 dog, 72.0ms
# Speed: 2.0ms preprocess, 72.0ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 71: Detected 21 people
#
# 0: 384x640 38 persons, 65.3ms
# Speed: 2.0ms preprocess, 65.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 72: Detected 24 people
#
# 0: 384x640 38 persons, 81.5ms
# Speed: 2.0ms preprocess, 81.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 73: Detected 24 people
#
# 0: 384x640 41 persons, 76.0ms
# Speed: 2.0ms preprocess, 76.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 74: Detected 25 people
#
# 0: 384x640 42 persons, 83.5ms
# Speed: 4.0ms preprocess, 83.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 75: Detected 25 people
#
# 0: 384x640 40 persons, 1 bird, 1 dog, 68.6ms
# Speed: 4.0ms preprocess, 68.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 76: Detected 24 people
#
# 0: 384x640 41 persons, 60.6ms
# Speed: 4.0ms preprocess, 60.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 77: Detected 25 people
#
# 0: 384x640 42 persons, 61.0ms
# Speed: 3.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 78: Detected 22 people
#
# 0: 384x640 41 persons, 1 bird, 67.1ms
# Speed: 3.0ms preprocess, 67.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 79: Detected 20 people
#
# 0: 384x640 40 persons, 68.0ms
# Speed: 2.0ms preprocess, 68.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 80: Detected 21 people
#
# 0: 384x640 40 persons, 3 birds, 77.5ms
# Speed: 3.0ms preprocess, 77.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 81: Detected 21 people
#
# 0: 384x640 37 persons, 3 birds, 79.5ms
# Speed: 4.0ms preprocess, 79.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 82: Detected 22 people
#
# 0: 384x640 41 persons, 76.6ms
# Speed: 3.0ms preprocess, 76.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 83: Detected 22 people
#
# 0: 384x640 38 persons, 75.6ms
# Speed: 4.0ms preprocess, 75.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 84: Detected 23 people
#
# 0: 384x640 38 persons, 1 bird, 74.6ms
# Speed: 4.0ms preprocess, 74.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 85: Detected 23 people
#
# 0: 384x640 38 persons, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 86: Detected 23 people
#
# 0: 384x640 37 persons, 75.0ms
# Speed: 4.0ms preprocess, 75.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 87: Detected 23 people
#
# 0: 384x640 36 persons, 64.5ms
# Speed: 5.0ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 88: Detected 24 people
#
# 0: 384x640 38 persons, 74.6ms
# Speed: 3.0ms preprocess, 74.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 89: Detected 23 people
# Processing progress: 26.4%
#
# 0: 384x640 38 persons, 77.5ms
# Speed: 2.0ms preprocess, 77.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 90: Detected 24 people
#
# 0: 384x640 40 persons, 69.0ms
# Speed: 5.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 91: Detected 23 people
#
# 0: 384x640 38 persons, 60.5ms
# Speed: 2.0ms preprocess, 60.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 92: Detected 24 people
#
# 0: 384x640 37 persons, 61.5ms
# Speed: 4.0ms preprocess, 61.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 93: Detected 23 people
#
# 0: 384x640 37 persons, 66.5ms
# Speed: 5.0ms preprocess, 66.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 94: Detected 22 people
#
# 0: 384x640 35 persons, 68.5ms
# Speed: 2.0ms preprocess, 68.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 95: Detected 21 people
#
# 0: 384x640 35 persons, 70.6ms
# Speed: 4.0ms preprocess, 70.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 96: Detected 19 people
#
# 0: 384x640 36 persons, 87.0ms
# Speed: 4.0ms preprocess, 87.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 97: Detected 19 people
#
# 0: 384x640 35 persons, 1 dog, 73.5ms
# Speed: 5.0ms preprocess, 73.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 98: Detected 23 people
# 0: 384x640 37 persons, 78.5ms
# Speed: 3.0ms preprocess, 78.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 99: Detected 22 people
#
# 0: 384x640 37 persons, 77.0ms
# Speed: 5.0ms preprocess, 77.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 100: Detected 23 people
#
# 0: 384x640 35 persons, 76.5ms
# Speed: 7.0ms preprocess, 76.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 101: Detected 23 people
#
# 0: 384x640 38 persons, 1 backpack, 66.5ms
# Speed: 3.0ms preprocess, 66.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 102: Detected 23 people
#
# 0: 384x640 37 persons, 1 dog, 66.2ms
# Speed: 3.0ms preprocess, 66.2ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 103: Detected 23 people
#
# 0: 384x640 38 persons, 1 bird, 73.6ms
# Speed: 2.0ms preprocess, 73.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 104: Detected 22 people
#
# 0: 384x640 36 persons, 73.6ms
# Speed: 4.0ms preprocess, 73.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 105: Detected 23 people
#
# 0: 384x640 35 persons, 70.5ms
# Speed: 3.0ms preprocess, 70.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 106: Detected 22 people
#
# 0: 384x640 33 persons, 1 bird, 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 107: Detected 22 people
#
# 0: 384x640 35 persons, 60.0ms
# Speed: 3.0ms preprocess, 60.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 108: Detected 23 people
#
# 0: 384x640 32 persons, 1 bird, 62.5ms
# Speed: 3.0ms preprocess, 62.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 109: Detected 22 people
#
# 0: 384x640 32 persons, 67.6ms
# Speed: 4.0ms preprocess, 67.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 110: Detected 22 people
#
# 0: 384x640 33 persons, 1 bird, 1 dog, 1 handbag, 1 suitcase, 72.5ms
# Speed: 4.0ms preprocess, 72.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 111: Detected 21 people
#
# 0: 384x640 32 persons, 1 handbag, 1 suitcase, 70.0ms
# Speed: 3.0ms preprocess, 70.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 112: Detected 21 people
#
# 0: 384x640 33 persons, 1 dog, 81.5ms
# Speed: 4.0ms preprocess, 81.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 113: Detected 21 people
#
# 0: 384x640 31 persons, 1 suitcase, 93.3ms
# Speed: 4.0ms preprocess, 93.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 114: Detected 23 people
#
# 0: 384x640 34 persons, 1 suitcase, 79.6ms
# Speed: 3.0ms preprocess, 79.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 115: Detected 24 people
#
# 0: 384x640 32 persons, 1 dog, 71.5ms
# Speed: 4.0ms preprocess, 71.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 116: Detected 21 people
#
# 0: 384x640 30 persons, 74.5ms
# Speed: 3.0ms preprocess, 74.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 117: Detected 22 people
#
# 0: 384x640 29 persons, 61.0ms
# Speed: 2.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 118: Detected 19 people
#
# 0: 384x640 28 persons, 1 bird, 62.0ms
# Speed: 2.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 119: Detected 19 people
# Processing progress: 35.2%
#
# 0: 384x640 30 persons, 113.6ms
# Speed: 3.0ms preprocess, 113.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 120: Detected 19 people
#
# 0: 384x640 32 persons, 1 dog, 105.5ms
# Speed: 5.0ms preprocess, 105.5ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 121: Detected 22 people
#
# 0: 384x640 33 persons, 1 dog, 102.5ms
# Speed: 4.0ms preprocess, 102.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 122: Detected 23 people
#
# 0: 384x640 32 persons, 1 bird, 70.6ms
# Speed: 3.0ms preprocess, 70.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 123: Detected 24 people
#
# 0: 384x640 35 persons, 72.5ms
# Speed: 3.0ms preprocess, 72.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 124: Detected 25 people
#
# 0: 384x640 37 persons, 1 bird, 70.0ms
# Speed: 5.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 125: Detected 26 people
#
# 0: 384x640 36 persons, 1 bird, 95.6ms
# Speed: 6.0ms preprocess, 95.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 126: Detected 26 people
#
# 0: 384x640 38 persons, 1 bird, 99.6ms
# Speed: 4.0ms preprocess, 99.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 127: Detected 27 people
#
# 0: 384x640 33 persons, 126.7ms
# Speed: 3.0ms preprocess, 126.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 128: Detected 25 people
#
# 0: 384x640 35 persons, 125.5ms
# Speed: 7.0ms preprocess, 125.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 129: Detected 23 people
#
# 0: 384x640 34 persons, 1 bird, 76.6ms
# Speed: 3.0ms preprocess, 76.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 130: Detected 24 people
#
# 0: 384x640 32 persons, 1 bird, 76.6ms
# Speed: 2.0ms preprocess, 76.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 131: Detected 23 people
#
# 0: 384x640 33 persons, 1 bird, 71.0ms
# Speed: 2.1ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 132: Detected 23 people
#
# 0: 384x640 31 persons, 68.0ms
# Speed: 4.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 133: Detected 22 people
#
# 0: 384x640 31 persons, 69.6ms
# Speed: 4.0ms preprocess, 69.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 134: Detected 23 people
#
# 0: 384x640 32 persons, 80.9ms
# Speed: 3.0ms preprocess, 80.9ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 135: Detected 23 people
#
# 0: 384x640 32 persons, 102.5ms
# Speed: 7.0ms preprocess, 102.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 136: Detected 25 people
#
# 0: 384x640 31 persons, 1 backpack, 88.6ms
# Speed: 5.0ms preprocess, 88.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 137: Detected 25 people
#
# 0: 384x640 31 persons, 1 suitcase, 202.1ms
# Speed: 17.0ms preprocess, 202.1ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 138: Detected 22 people
#
# 0: 384x640 33 persons, 1 suitcase, 155.1ms
# Speed: 6.0ms preprocess, 155.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 139: Detected 19 people
#
# 0: 384x640 30 persons, 1 suitcase, 161.7ms
# Speed: 7.0ms preprocess, 161.7ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 140: Detected 19 people
#
# 0: 384x640 33 persons, 135.5ms
# Speed: 8.0ms preprocess, 135.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 141: Detected 20 people
#
# 0: 384x640 28 persons, 1 suitcase, 93.5ms
# Speed: 6.0ms preprocess, 93.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 142: Detected 22 people
#
# 0: 384x640 30 persons, 132.1ms
# Speed: 5.0ms preprocess, 132.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 143: Detected 23 people
#
# 0: 384x640 30 persons, 115.1ms
# Speed: 4.0ms preprocess, 115.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 144: Detected 25 people
#
# 0: 384x640 31 persons, 148.1ms
# Speed: 6.0ms preprocess, 148.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 145: Detected 25 people
#
# 0: 384x640 30 persons, 139.5ms
# Speed: 9.0ms preprocess, 139.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 146: Detected 24 people
#
# 0: 384x640 29 persons, 101.5ms
# Speed: 5.0ms preprocess, 101.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 147: Detected 23 people
#
# 0: 384x640 30 persons, 1 horse, 116.0ms
# Speed: 9.0ms preprocess, 116.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 148: Detected 23 people
#
# 0: 384x640 30 persons, 146.1ms
# Speed: 4.0ms preprocess, 146.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 149: Detected 23 people
# Processing progress: 44.0%
#
# 0: 384x640 30 persons, 120.9ms
# Speed: 5.5ms preprocess, 120.9ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 150: Detected 25 people
#
# 0: 384x640 30 persons, 94.5ms
# Speed: 3.0ms preprocess, 94.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 151: Detected 23 people
#
# 0: 384x640 30 persons, 1 bird, 101.5ms
# Speed: 5.0ms preprocess, 101.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 152: Detected 23 people
#
# 0: 384x640 28 persons, 1 bird, 87.5ms
# Speed: 4.0ms preprocess, 87.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 153: Detected 19 people
#
# 0: 384x640 29 persons, 85.5ms
# Speed: 3.0ms preprocess, 85.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 154: Detected 22 people
#
# 0: 384x640 29 persons, 93.5ms
# Speed: 4.0ms preprocess, 93.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 155: Detected 24 people
#
# 0: 384x640 30 persons, 119.6ms
# Speed: 5.0ms preprocess, 119.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 156: Detected 25 people
#
# 0: 384x640 30 persons, 105.6ms
# Speed: 5.0ms preprocess, 105.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 157: Detected 24 people
#
# 0: 384x640 29 persons, 113.5ms
# Speed: 5.0ms preprocess, 113.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 158: Detected 22 people
#
# 0: 384x640 26 persons, 1 bird, 118.6ms
# Speed: 7.0ms preprocess, 118.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 159: Detected 23 people
#
# 0: 384x640 29 persons, 1 bird, 95.6ms
# Speed: 3.0ms preprocess, 95.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 160: Detected 23 people
#
# 0: 384x640 30 persons, 102.5ms
# Speed: 5.0ms preprocess, 102.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 161: Detected 24 people
#
# 0: 384x640 28 persons, 1 bird, 115.5ms
# Speed: 6.0ms preprocess, 115.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 162: Detected 23 people
#
# 0: 384x640 30 persons, 90.5ms
# Speed: 9.0ms preprocess, 90.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 163: Detected 25 people
#
# 0: 384x640 29 persons, 100.6ms
# Speed: 4.0ms preprocess, 100.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 164: Detected 23 people
#
# 0: 384x640 29 persons, 99.5ms
# Speed: 3.0ms preprocess, 99.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 165: Detected 24 people
#
# 0: 384x640 31 persons, 93.6ms
# Speed: 4.0ms preprocess, 93.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 166: Detected 23 people
#
# 0: 384x640 30 persons, 90.5ms
# Speed: 5.0ms preprocess, 90.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 167: Detected 22 people
#
# 0: 384x640 30 persons, 126.5ms
# Speed: 7.0ms preprocess, 126.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 168: Detected 23 people
#
# 0: 384x640 30 persons, 87.5ms
# Speed: 4.0ms preprocess, 87.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 169: Detected 24 people
#
# 0: 384x640 30 persons, 71.5ms
# Speed: 3.0ms preprocess, 71.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 170: Detected 24 people
#
# 0: 384x640 29 persons, 72.5ms
# Speed: 5.0ms preprocess, 72.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 171: Detected 25 people
#
# 0: 384x640 30 persons, 72.0ms
# Speed: 5.0ms preprocess, 72.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 172: Detected 24 people
#
# 0: 384x640 28 persons, 75.5ms
# Speed: 4.0ms preprocess, 75.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 173: Detected 23 people
#
# 0: 384x640 29 persons, 90.0ms
# Speed: 6.0ms preprocess, 90.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 174: Detected 23 people
#
# 0: 384x640 29 persons, 71.5ms
# Speed: 5.0ms preprocess, 71.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 175: Detected 22 people
#
# 0: 384x640 29 persons, 1 bird, 92.5ms
# Speed: 5.0ms preprocess, 92.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 176: Detected 23 people
#
# 0: 384x640 29 persons, 93.5ms
# Speed: 5.0ms preprocess, 93.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 177: Detected 24 people
#
# 0: 384x640 30 persons, 1 bird, 72.0ms
# Speed: 4.5ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 178: Detected 25 people
#
# 0: 384x640 29 persons, 70.0ms
# Speed: 3.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 179: Detected 25 people
# Processing progress: 52.8%
#
# 0: 384x640 28 persons, 66.1ms
# Speed: 2.0ms preprocess, 66.1ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 180: Detected 23 people
#
# 0: 384x640 30 persons, 82.6ms
# Speed: 3.0ms preprocess, 82.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 181: Detected 24 people
#
# 0: 384x640 30 persons, 116.5ms
# Speed: 5.0ms preprocess, 116.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 182: Detected 22 people
#
# 0: 384x640 27 persons, 77.5ms
# Speed: 6.0ms preprocess, 77.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 183: Detected 22 people
#
# 0: 384x640 30 persons, 77.6ms
# Speed: 4.0ms preprocess, 77.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 184: Detected 21 people
#
# 0: 384x640 27 persons, 74.5ms
# Speed: 4.0ms preprocess, 74.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 185: Detected 24 people
#
# 0: 384x640 28 persons, 74.0ms
# Speed: 3.0ms preprocess, 74.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 186: Detected 23 people
#
# 0: 384x640 28 persons, 66.5ms
# Speed: 2.0ms preprocess, 66.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 187: Detected 23 people
#
# 0: 384x640 28 persons, 73.5ms
# Speed: 5.0ms preprocess, 73.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 188: Detected 23 people
#
# 0: 384x640 29 persons, 72.0ms
# Speed: 3.0ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 189: Detected 24 people
#
# 0: 384x640 30 persons, 1 backpack, 75.5ms
# Speed: 3.0ms preprocess, 75.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 190: Detected 25 people
#
# 0: 384x640 30 persons, 73.6ms
# Speed: 3.0ms preprocess, 73.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 191: Detected 26 people
#
# 0: 384x640 30 persons, 67.5ms
# Speed: 4.0ms preprocess, 67.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 192: Detected 27 people
#
# 0: 384x640 31 persons, 61.0ms
# Speed: 3.0ms preprocess, 61.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 193: Detected 25 people
#
# 0: 384x640 32 persons, 1 skis, 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 194: Detected 25 people
#
# 0: 384x640 32 persons, 1 skis, 64.0ms
# Speed: 4.0ms preprocess, 64.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 195: Detected 25 people
#
# 0: 384x640 31 persons, 1 backpack, 81.6ms
# Speed: 5.0ms preprocess, 81.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 196: Detected 24 people
#
# 0: 384x640 33 persons, 1 backpack, 76.5ms
# Speed: 3.0ms preprocess, 76.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 197: Detected 25 people
#
# 0: 384x640 34 persons, 1 handbag, 72.6ms
# Speed: 4.0ms preprocess, 72.6ms inference, 1.9ms postprocess per image at shape (1, 3, 384, 640)
# Frame 198: Detected 24 people
#
# 0: 384x640 35 persons, 1 handbag, 64.6ms
# Speed: 2.0ms preprocess, 64.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 199: Detected 22 people
#
# 0: 384x640 32 persons, 1 handbag, 64.6ms
# Speed: 3.0ms preprocess, 64.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 200: Detected 22 people
#
# 0: 384x640 34 persons, 1 dog, 72.6ms
# Speed: 4.0ms preprocess, 72.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 201: Detected 21 people
#
# 0: 384x640 32 persons, 69.5ms
# Speed: 2.0ms preprocess, 69.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 202: Detected 21 people
#
# 0: 384x640 32 persons, 1 motorcycle, 1 handbag, 65.0ms
# Speed: 3.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 203: Detected 22 people
#
# 0: 384x640 32 persons, 1 handbag, 75.6ms
# Speed: 3.0ms preprocess, 75.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 204: Detected 21 people
#
# 0: 384x640 31 persons, 1 motorcycle, 1 handbag, 79.6ms
# Speed: 4.0ms preprocess, 79.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 205: Detected 23 people
#
# 0: 384x640 32 persons, 1 horse, 1 handbag, 71.7ms
# Speed: 4.0ms preprocess, 71.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 206: Detected 22 people
#
# 0: 384x640 32 persons, 2 motorcycles, 1 horse, 1 handbag, 69.0ms
# Speed: 4.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 207: Detected 23 people
#
# 0: 384x640 29 persons, 1 horse, 1 backpack, 109.6ms
# Speed: 3.0ms preprocess, 109.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 208: Detected 21 people
#
# 0: 384x640 28 persons, 108.5ms
# Speed: 7.0ms preprocess, 108.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 209: Detected 21 people
# Processing progress: 61.6%
#
# 0: 384x640 27 persons, 1 motorcycle, 83.5ms
# Speed: 4.0ms preprocess, 83.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 210: Detected 20 people
#
# 0: 384x640 26 persons, 1 motorcycle, 1 dog, 75.0ms
# Speed: 4.0ms preprocess, 75.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 211: Detected 16 people
#
# 0: 384x640 28 persons, 1 dog, 1 backpack, 84.6ms
# Speed: 4.0ms preprocess, 84.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 212: Detected 17 people
#
# 0: 384x640 28 persons, 1 motorcycle, 1 backpack, 79.5ms
# Speed: 3.0ms preprocess, 79.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 213: Detected 16 people
#
# 0: 384x640 29 persons, 71.0ms
# Speed: 2.0ms preprocess, 71.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 214: Detected 15 people
#
# 0: 384x640 28 persons, 1 backpack, 1 handbag, 70.5ms
# Speed: 5.0ms preprocess, 70.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 215: Detected 17 people
#
# 0: 384x640 28 persons, 1 backpack, 1 handbag, 72.5ms
# Speed: 3.0ms preprocess, 72.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 216: Detected 16 people
#
# 0: 384x640 28 persons, 1 dog, 1 backpack, 1 handbag, 72.0ms
# Speed: 5.0ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 217: Detected 18 people
#
# 0: 384x640 29 persons, 1 handbag, 67.0ms
# Speed: 2.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 218: Detected 20 people
#
# 0: 384x640 31 persons, 1 handbag, 76.5ms
# Speed: 4.0ms preprocess, 76.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 219: Detected 20 people
#
# 0: 384x640 31 persons, 1 handbag, 93.6ms
# Speed: 4.0ms preprocess, 93.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 220: Detected 22 people
#
# 0: 384x640 31 persons, 1 handbag, 83.5ms
# Speed: 4.0ms preprocess, 83.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 221: Detected 22 people
#
# 0: 384x640 29 persons, 1 handbag, 64.5ms
# Speed: 2.0ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 222: Detected 22 people
#
# 0: 384x640 28 persons, 1 skis, 65.5ms
# Speed: 3.0ms preprocess, 65.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 223: Detected 21 people
#
# 0: 384x640 29 persons, 1 skis, 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 224: Detected 21 people
#
# 0: 384x640 24 persons, 1 bird, 1 skis, 62.6ms
# Speed: 3.0ms preprocess, 62.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 225: Detected 20 people
#
# 0: 384x640 27 persons, 1 bird, 1 horse, 1 handbag, 1 skis, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 226: Detected 18 people
#
# 0: 384x640 27 persons, 1 bird, 1 handbag, 1 skis, 80.0ms
# Speed: 3.0ms preprocess, 80.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 227: Detected 18 people
#
# 0: 384x640 26 persons, 1 bird, 1 handbag, 1 skis, 95.5ms
# Speed: 4.0ms preprocess, 95.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 228: Detected 18 people
#
# 0: 384x640 26 persons, 1 dog, 1 handbag, 90.0ms
# Speed: 6.0ms preprocess, 90.0ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 229: Detected 17 people
#
# 0: 384x640 28 persons, 1 handbag, 73.5ms
# Speed: 3.0ms preprocess, 73.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 230: Detected 18 people
#
# 0: 384x640 30 persons, 1 handbag, 76.5ms
# Speed: 2.0ms preprocess, 76.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 231: Detected 18 people
#
# 0: 384x640 30 persons, 2 handbags, 97.5ms
# Speed: 4.5ms preprocess, 97.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 232: Detected 19 people
#
# 0: 384x640 29 persons, 1 horse, 1 backpack, 1 handbag, 71.6ms
# Speed: 5.0ms preprocess, 71.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 233: Detected 18 people
#
# 0: 384x640 28 persons, 1 handbag, 69.5ms
# Speed: 3.0ms preprocess, 69.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 234: Detected 16 people
#
# 0: 384x640 28 persons, 1 handbag, 82.0ms
# Speed: 5.0ms preprocess, 82.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 235: Detected 17 people
#
# 0: 384x640 26 persons, 2 dogs, 70.6ms
# Speed: 5.0ms preprocess, 70.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 236: Detected 16 people
#
# 0: 384x640 26 persons, 1 dog, 1 handbag, 73.0ms
# Speed: 2.5ms preprocess, 73.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 237: Detected 16 people
#
# 0: 384x640 27 persons, 1 dog, 1 handbag, 65.0ms
# Speed: 3.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 238: Detected 16 people
#
# 0: 384x640 27 persons, 1 dog, 1 backpack, 75.5ms
# Speed: 4.0ms preprocess, 75.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 239: Detected 16 people
# Processing progress: 70.4%
#
# 0: 384x640 27 persons, 1 backpack, 72.6ms
# Speed: 3.0ms preprocess, 72.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 240: Detected 16 people
#
# 0: 384x640 26 persons, 1 bird, 1 backpack, 70.6ms
# Speed: 4.0ms preprocess, 70.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 241: Detected 16 people
#
# 0: 384x640 26 persons, 1 bird, 1 backpack, 69.0ms
# Speed: 3.0ms preprocess, 69.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 242: Detected 15 people
#
# 0: 384x640 28 persons, 1 bird, 1 handbag, 68.5ms
# Speed: 3.0ms preprocess, 68.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 243: Detected 15 people
#
# 0: 384x640 26 persons, 1 bird, 1 handbag, 70.5ms
# Speed: 3.0ms preprocess, 70.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 244: Detected 16 people
#
# 0: 384x640 27 persons, 1 bird, 1 handbag, 65.6ms
# Speed: 1.0ms preprocess, 65.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 245: Detected 14 people
#
# 0: 384x640 25 persons, 1 motorcycle, 1 handbag, 77.6ms
# Speed: 3.0ms preprocess, 77.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 246: Detected 15 people
#
# 0: 384x640 25 persons, 1 motorcycle, 1 bird, 66.0ms
# Speed: 3.0ms preprocess, 66.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 247: Detected 15 people
#
# 0: 384x640 25 persons, 1 motorcycle, 1 handbag, 74.6ms
# Speed: 2.0ms preprocess, 74.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 248: Detected 16 people
#
# 0: 384x640 24 persons, 2 birds, 1 handbag, 73.5ms
# Speed: 4.0ms preprocess, 73.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 249: Detected 13 people
#
# 0: 384x640 25 persons, 2 birds, 1 dog, 71.5ms
# Speed: 3.0ms preprocess, 71.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 250: Detected 15 people
#
# 0: 384x640 25 persons, 2 birds, 1 dog, 1 handbag, 91.5ms
# Speed: 5.0ms preprocess, 91.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 251: Detected 14 people
#
# 0: 384x640 25 persons, 1 handbag, 107.5ms
# Speed: 8.0ms preprocess, 107.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 252: Detected 17 people
#
# 0: 384x640 27 persons, 1 handbag, 83.7ms
# Speed: 7.0ms preprocess, 83.7ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 253: Detected 14 people
#
# 0: 384x640 28 persons, 1 handbag, 79.4ms
# Speed: 4.0ms preprocess, 79.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 254: Detected 18 people
#
# 0: 384x640 29 persons, 1 handbag, 77.7ms
# Speed: 4.9ms preprocess, 77.7ms inference, 2.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 255: Detected 19 people
#
# 0: 384x640 30 persons, 1 bird, 1 handbag, 86.4ms
# Speed: 4.3ms preprocess, 86.4ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 256: Detected 18 people
#
# 0: 384x640 29 persons, 73.6ms
# Speed: 3.0ms preprocess, 73.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 257: Detected 17 people
#
# 0: 384x640 28 persons, 70.0ms
# Speed: 3.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 258: Detected 19 people
#
# 0: 384x640 28 persons, 73.6ms
# Speed: 4.0ms preprocess, 73.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 259: Detected 17 people
#
# 0: 384x640 29 persons, 1 backpack, 83.5ms
# Speed: 2.0ms preprocess, 83.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 260: Detected 17 people
#
# 0: 384x640 28 persons, 1 backpack, 1 handbag, 74.0ms
# Speed: 5.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 261: Detected 19 people
#
# 0: 384x640 26 persons, 1 backpack, 1 handbag, 76.5ms
# Speed: 5.0ms preprocess, 76.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 262: Detected 20 people
#
# 0: 384x640 26 persons, 1 dog, 1 handbag, 64.5ms
# Speed: 4.0ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 263: Detected 20 people
#
# 0: 384x640 29 persons, 2 birds, 1 handbag, 72.3ms
# Speed: 3.0ms preprocess, 72.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 264: Detected 17 people
#
# 0: 384x640 27 persons, 1 handbag, 97.5ms
# Speed: 3.0ms preprocess, 97.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 265: Detected 15 people
#
# 0: 384x640 28 persons, 85.6ms
# Speed: 6.0ms preprocess, 85.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 266: Detected 17 people
#
# 0: 384x640 30 persons, 1 bird, 84.6ms
# Speed: 3.0ms preprocess, 84.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 267: Detected 18 people
#
# 0: 384x640 26 persons, 1 bird, 1 backpack, 87.5ms
# Speed: 4.0ms preprocess, 87.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 268: Detected 16 people
#
# 0: 384x640 28 persons, 1 bird, 1 handbag, 70.0ms
# Speed: 4.0ms preprocess, 70.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 269: Detected 18 people
# Processing progress: 79.2%
#
# 0: 384x640 29 persons, 1 bird, 1 handbag, 63.5ms
# Speed: 3.0ms preprocess, 63.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 270: Detected 15 people
#
# 0: 384x640 28 persons, 1 bird, 79.6ms
# Speed: 3.0ms preprocess, 79.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 271: Detected 16 people
#
# 0: 384x640 27 persons, 1 backpack, 81.0ms
# Speed: 4.0ms preprocess, 81.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
# Frame 272: Detected 16 people
#
# 0: 384x640 26 persons, 1 bird, 1 handbag, 69.5ms
# Speed: 6.0ms preprocess, 69.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 273: Detected 17 people
#
# 0: 384x640 30 persons, 1 bird, 64.5ms
# Speed: 2.0ms preprocess, 64.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 274: Detected 19 people
#
# 0: 384x640 29 persons, 1 bird, 65.6ms
# Speed: 3.0ms preprocess, 65.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 275: Detected 17 people
#
# 0: 384x640 29 persons, 1 bird, 1 handbag, 64.0ms
# Speed: 4.0ms preprocess, 64.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 276: Detected 16 people
#
# 0: 384x640 29 persons, 1 handbag, 70.0ms
# Speed: 3.0ms preprocess, 70.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 277: Detected 14 people
#
# 0: 384x640 30 persons, 2 handbags, 76.5ms
# Speed: 2.0ms preprocess, 76.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 278: Detected 15 people
#
# 0: 384x640 31 persons, 3 handbags, 79.6ms
# Speed: 4.0ms preprocess, 79.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 279: Detected 15 people
#
# 0: 384x640 32 persons, 1 handbag, 103.6ms
# Speed: 5.0ms preprocess, 103.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 280: Detected 15 people
#
# 0: 384x640 30 persons, 2 handbags, 84.6ms
# Speed: 3.0ms preprocess, 84.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 281: Detected 15 people
#
# 0: 384x640 30 persons, 1 handbag, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 282: Detected 18 people
#
# 0: 384x640 30 persons, 1 dog, 1 handbag, 94.5ms
# Speed: 5.0ms preprocess, 94.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 283: Detected 18 people
#
# 0: 384x640 28 persons, 1 handbag, 74.0ms
# Speed: 6.0ms preprocess, 74.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 284: Detected 20 people
#
# 0: 384x640 28 persons, 1 dog, 67.5ms
# Speed: 3.0ms preprocess, 67.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 285: Detected 20 people
#
# 0: 384x640 29 persons, 1 dog, 64.5ms
# Speed: 5.0ms preprocess, 64.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 286: Detected 19 people
#
# 0: 384x640 29 persons, 1 dog, 71.6ms
# Speed: 2.0ms preprocess, 71.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 287: Detected 19 people
#
# 0: 384x640 28 persons, 1 bird, 1 dog, 68.5ms
# Speed: 6.0ms preprocess, 68.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 288: Detected 19 people
#
# 0: 384x640 26 persons, 1 bird, 1 dog, 1 backpack, 67.0ms
# Speed: 4.0ms preprocess, 67.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 289: Detected 19 people
#
# 0: 384x640 27 persons, 1 bird, 2 backpacks, 65.0ms
# Speed: 2.0ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 290: Detected 21 people
#
# 0: 384x640 29 persons, 69.6ms
# Speed: 3.0ms preprocess, 69.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 291: Detected 20 people
#
# 0: 384x640 29 persons, 71.6ms
# Speed: 2.0ms preprocess, 71.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 292: Detected 17 people
#
# 0: 384x640 31 persons, 65.0ms
# Speed: 3.5ms preprocess, 65.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 293: Detected 18 people
#
# 0: 384x640 34 persons, 63.0ms
# Speed: 5.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 294: Detected 16 people
#
# 0: 384x640 29 persons, 72.0ms
# Speed: 4.0ms preprocess, 72.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 295: Detected 19 people
#
# 0: 384x640 30 persons, 1 backpack, 69.5ms
# Speed: 2.0ms preprocess, 69.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 296: Detected 18 people
#
# 0: 384x640 32 persons, 1 backpack, 76.5ms
# Speed: 4.0ms preprocess, 76.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 297: Detected 19 people
#
# 0: 384x640 30 persons, 1 bird, 1 backpack, 61.6ms
# Speed: 3.0ms preprocess, 61.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 298: Detected 18 people
#
# 0: 384x640 30 persons, 1 bird, 1 dog, 1 backpack, 64.0ms
# Speed: 2.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 299: Detected 16 people
# Processing progress: 88.0%
#
# 0: 384x640 31 persons, 1 bird, 63.0ms
# Speed: 2.0ms preprocess, 63.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 300: Detected 15 people
#
# 0: 384x640 29 persons, 1 dog, 73.5ms
# Speed: 4.0ms preprocess, 73.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 301: Detected 16 people
#
# 0: 384x640 28 persons, 1 dog, 69.6ms
# Speed: 3.0ms preprocess, 69.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 302: Detected 15 people
#
# 0: 384x640 29 persons, 1 dog, 70.5ms
# Speed: 3.0ms preprocess, 70.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 303: Detected 17 people
#
# 0: 384x640 28 persons, 66.0ms
# Speed: 2.0ms preprocess, 66.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 304: Detected 17 people
#
# 0: 384x640 26 persons, 1 bird, 68.0ms
# Speed: 3.0ms preprocess, 68.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 305: Detected 16 people
#
# 0: 384x640 28 persons, 1 bird, 62.0ms
# Speed: 3.0ms preprocess, 62.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 306: Detected 16 people
#
# 0: 384x640 29 persons, 1 bird, 1 umbrella, 65.5ms
# Speed: 2.0ms preprocess, 65.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 307: Detected 16 people
#
# 0: 384x640 31 persons, 58.5ms
# Speed: 3.0ms preprocess, 58.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 308: Detected 17 people
#
# 0: 384x640 28 persons, 1 bird, 1 dog, 1 umbrella, 77.6ms
# Speed: 3.0ms preprocess, 77.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 309: Detected 17 people
#
# 0: 384x640 31 persons, 2 dogs, 64.5ms
# Speed: 3.0ms preprocess, 64.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 310: Detected 19 people
#
# 0: 384x640 25 persons, 1 dog, 70.0ms
# Speed: 3.5ms preprocess, 70.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 311: Detected 19 people
#
# 0: 384x640 28 persons, 1 dog, 73.0ms
# Speed: 2.0ms preprocess, 73.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 312: Detected 20 people
#
# 0: 384x640 29 persons, 1 dog, 78.5ms
# Speed: 4.0ms preprocess, 78.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 313: Detected 19 people
#
# 0: 384x640 29 persons, 1 dog, 96.5ms
# Speed: 7.5ms preprocess, 96.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 314: Detected 16 people
#
# 0: 384x640 26 persons, 1 dog, 77.5ms
# Speed: 6.0ms preprocess, 77.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 315: Detected 17 people
#
# 0: 384x640 28 persons, 1 dog, 63.5ms
# Speed: 3.0ms preprocess, 63.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 316: Detected 19 people
#
# 0: 384x640 29 persons, 1 dog, 68.0ms
# Speed: 2.5ms preprocess, 68.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 317: Detected 20 people
#
# 0: 384x640 28 persons, 64.0ms
# Speed: 5.0ms preprocess, 64.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 318: Detected 20 people
#
# 0: 384x640 28 persons, 1 umbrella, 63.0ms
# Speed: 3.0ms preprocess, 63.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 319: Detected 18 people
#
# 0: 384x640 29 persons, 74.6ms
# Speed: 2.0ms preprocess, 74.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 320: Detected 19 people
#
# 0: 384x640 31 persons, 84.5ms
# Speed: 4.0ms preprocess, 84.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 321: Detected 17 people
#
# 0: 384x640 31 persons, 78.0ms
# Speed: 4.0ms preprocess, 78.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 322: Detected 20 people
#
# 0: 384x640 30 persons, 74.5ms
# Speed: 3.0ms preprocess, 74.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 323: Detected 20 people
#
# 0: 384x640 29 persons, 63.5ms
# Speed: 2.0ms preprocess, 63.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 324: Detected 20 people
#
# 0: 384x640 28 persons, 67.6ms
# Speed: 3.0ms preprocess, 67.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 325: Detected 21 people
#
# 0: 384x640 28 persons, 61.6ms
# Speed: 2.0ms preprocess, 61.6ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 326: Detected 21 people
#
# 0: 384x640 29 persons, 64.0ms
# Speed: 3.0ms preprocess, 64.0ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 327: Detected 23 people
#
# 0: 384x640 28 persons, 76.5ms
# Speed: 2.0ms preprocess, 76.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 328: Detected 23 people
#
# 0: 384x640 29 persons, 99.5ms
# Speed: 7.0ms preprocess, 99.5ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 329: Detected 21 people
# Processing progress: 96.8%
#
# 0: 384x640 30 persons, 1 dog, 94.5ms
# Speed: 3.0ms preprocess, 94.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 330: Detected 18 people
#
# 0: 384x640 29 persons, 1 dog, 65.5ms
# Speed: 3.0ms preprocess, 65.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 331: Detected 23 people
#
# 0: 384x640 28 persons, 73.5ms
# Speed: 3.0ms preprocess, 73.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 332: Detected 20 people
#
# 0: 384x640 28 persons, 76.0ms
# Speed: 4.0ms preprocess, 76.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 333: Detected 22 people
#
# 0: 384x640 33 persons, 81.6ms
# Speed: 5.0ms preprocess, 81.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 334: Detected 24 people
#
# 0: 384x640 32 persons, 68.5ms
# Speed: 2.0ms preprocess, 68.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 335: Detected 24 people
#
# 0: 384x640 31 persons, 83.0ms
# Speed: 2.0ms preprocess, 83.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 336: Detected 25 people
#
# 0: 384x640 29 persons, 1 bird, 78.5ms
# Speed: 4.0ms preprocess, 78.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 337: Detected 21 people
#
# 0: 384x640 29 persons, 1 bird, 69.5ms
# Speed: 2.0ms preprocess, 69.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 338: Detected 21 people
#
# 0: 384x640 32 persons, 109.5ms
# Speed: 3.0ms preprocess, 109.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 339: Detected 22 people
#
# 0: 384x640 33 persons, 76.5ms
# Speed: 3.0ms preprocess, 76.5ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 340: Detected 22 people
#
# 0: 384x640 32 persons, 1 bird, 64.6ms
# Speed: 3.0ms preprocess, 64.6ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# Frame 341: Detected 20 people
#
# Processing completed!
# Results saved to: crowd_detection_results\crowd_detection_20241117_121324.csv
